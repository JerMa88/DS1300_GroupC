# %%
import pandas as pd
dialogue = pd.read_csv("../data/marvel-dialogue-nlp-master/data/mcu.csv")

# %%
dialogue
# Out:
#        Unnamed: 0       character  \
# 0               0      TONY STARK
# 1               1  IRON MAN JIMMY
# 2               2      TONY STARK
# 3               3         RAMIREZ
# 4               4      TONY STARK
# ...           ...             ...
# 15719       15719    STEVE ROGERS
# 15720       15720      SAM WILSON
# 15721       15721    STEVE ROGERS
# 15722       15722      SAM WILSON
# 15723       15723    STEVE ROGERS
#
#                                                     line              movie  \
# 0      Oh, I get it.  You guys aren’t allowed to talk...           Iron Man
# 1                            No.  We’re allowed to talk.           Iron Man
# 2                         Oh.  I see.  So it’s personal.           Iron Man
# 3                           I think they’re intimidated.           Iron Man
# 4      Good God, you’re a woman. I, honestly, I could...           Iron Man
# ...                                                  ...                ...
# ...

# %%
dialogue['line'] = dialogue['line'].apply(lambda x: " ".join(x.lower() for x in x.split()))
dialogue['line'].head()
# Out:
# 0    oh, i get it. you guys aren’t allowed to talk....
# 1                           no. we’re allowed to talk.
# 2                         oh. i see. so it’s personal.
# 3                         i think they’re intimidated.
# 4    good god, you’re a woman. i, honestly, i could...
# Name: line, dtype: object

# %%
dialogue['line'] = dialogue['line'].str.replace('[^\w\s]','')
dialogue['line'].head()
# Out:
# /tmp/ipykernel_2163392/3055096476.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dialogue['line'] = dialogue['line'].str.replace('[^\w\s]','')
# 0    oh i get it you guys arent allowed to talk is ...
# 1                              no were allowed to talk
# 2                             oh i see so its personal
# 3                           i think theyre intimidated
# 4    good god youre a woman i honestly i couldnt ha...
# Name: line, dtype: object

# %%
catchphrases=['iron man']

# %%
dialogue['Catchphrase-IM']=dialogue['line'].apply(lambda x: "iron man" in x)

# %%
dialogue[dialogue['Catchphrase-IM']==True]
# Out:
#        Unnamed: 0         character  \
# 679           679        TONY STARK
# 683           683        TONY STARK
# 691           691        TONY STARK
# 755           755     SENATOR STERN
# 763           763     SENATOR STERN
# 764           764        TONY STARK
# 769           769     JUSTIN HAMMER
# 776           776     SENATOR STERN
# 783           783      JAMES RHODES
# 813           813            JARVIS
# 1086         1086     SENATOR STERN
# 1129         1129      PEPPER POTTS
# 1149         1149     JUSTIN HAMMER
# 1164         1164      JAMES RHODES
# 1197         1197        TONY STARK
# 1237         1237         NICK FURY
# 1260         1260     JUSTIN HAMMER
# 1329         1329    STRAWBERRY MAN
# 1340         1340     NEWS REPORTER
# 1368         1368      PEPPER POTTS
# 1458         1458     JUSTIN HAMMER
# 1667         1667        TONY STARK
# 4104         4104          REPORTER
# 4352         4352       HAPPY HOGAN
# 4562         4562     HARLEY KEENER
# ...

# %%
dialogue['line'][683]
# Out:
# 'ive seen the papers ive heard the reports thats why i want to put an end to all this wild speculation the truth is i am iron man'

# %%
dialogue['Catchphrase-IR']=dialogue['line'].apply(lambda x: "i am iron man" in x)

# %%
dialogue[dialogue['Catchphrase-IR']==True]
# Out:
#       Unnamed: 0   character  \
# 683          683  TONY STARK
# 691          691  TONY STARK
# 764          764  TONY STARK
# 5122        5122  TONY STARK
#
#                                                    line       movie  year  \
# 683   ive seen the papers ive heard the reports that...    Iron Man  2008
# 691   i know that its confusing it is one thing to q...  Iron Man 2  2010
# 764   well you can forget it i am iron man the suit ...  Iron Man 2  2010
# 5122  so if i were to wrap this up tie it with a bow...  Iron Man 3  2013
#
#       words  Adam McKay  Anna Boden  Art Marcum  Ashley Edward Miller  ...  \
# 683      31       False       False        True                 False  ...
# 691      58       False       False       False                 False  ...
# 764      46       False       False       False                 False  ...
# 5122    168       False       False       False                 False  ...
#
# ...

# %%
dialogue['Catchphrase-AD']=dialogue['line'].apply(lambda x: "i can do this all day" in x)

# %%
dialogue[dialogue['Catchphrase-AD']==True]
# Out:
#        Unnamed: 0     character  \
# 2574         2574  STEVE ROGERS
# 3129         3129  STEVE ROGERS
# 9335         9335  STEVE ROGERS
# 15217       15217      A1 STEVE
#
#                                                     line  \
# 2574                               i can do this all day
# 3129   nothin im just a kid from brooklyn i can do th...
# 9335                               i can do this all day
# 15217                              i can do this all day
#
#                                     movie  year  words  Adam McKay  \
# 2574   Captain America: The First Avenger  2011      6       False
# 3129   Captain America: The First Avenger  2011     14       False
# 9335           Captain America: Civil War  2016      6       False
# 15217                   Avengers: Endgame  2019      6       False
#
#        Anna Boden  Art Marcum  Ashley Edward Miller  ...  Matt Holloway  \
# 2574        False       False                 False  ...          False
# ...

# %%
dialogue['Catchphrase-AA']=dialogue['line'].apply(lambda x: "avengersassemble" in x)

# %%
dialogue[dialogue['Catchphrase-AA']==True]
# Out:
#        Unnamed: 0     character              line              movie  year  \
# 15592       15592  STEVE ROGERS  avengersassemble  Avengers: Endgame  2019
#
#        words  Adam McKay  Anna Boden  Art Marcum  Ashley Edward Miller  ...  \
# 15592      1       False       False       False                 False  ...
#
#        Paul Rudd  Ryan Coogler  Ryan Fleck  Shane Black  Stephen McFeely  \
# 15592      False         False       False        False             True
#
#        Zack Stentz  Catchphrase-IM  Catchphrase-IR  Catchphrase-AD  \
# 15592        False           False           False           False
#
#        Catchphrase-AA
# 15592            True
#
# [1 rows x 42 columns]

# %%
dialogue['line'][691]
# Out:
# 'i know that its confusing it is one thing to question the official story and another thing entirely to make wild accusations or insinuate that im a superhero i mean lets face it im not the heroric type a laundry list of character defects all the mistakes ive made largely public the truth is i am iron man'

# %%
dialogue['line'][764]
# Out:
# 'well you can forget it i am iron man the suit and i are one to turn over the iron man suit would be to turn over myself which is tantamount to indentured servitude or prostitution depending or what state youre in you cant have it'

# %%
dialogue['line'][5122]
# Out:
# 'so if i were to wrap this up tie it with a bow or whatever i guess id say my armor it was never a distraction or a hobby it was a cocoon and now im a changed man you can take away my house all my tricks and toys one thing you cant take away i am iron man you know and thank you by the way for listening plus something about just getting it off my chest and putting it out there in the atmosphere instead of holding this in i mean this is what gets people sick you know wow i had no idea you were such a good listener to be able to share all my intimate thoughts and my experiences with someone it just cuts the weight of it in half you know its like a snake swallowing its own tail everything comes full circle and the fact that youve been able to help me process are you with me'

# %%
''.join(dialogue['line'][15645].split(" "))
# Out:
# 'andiamironman'

# %%
dialogue['compressed']=dialogue['line'].apply(lambda x: ''.join(x.split(" ")))

# %%
dialogue['CP_IM_compressed']=dialogue['compressed'].apply(lambda x: "iamironman" in x)

# %%
dialogue[dialogue['CP_IM_compressed']==True]
# Out:
#        Unnamed: 0   character  \
# 683           683  TONY STARK
# 691           691  TONY STARK
# 764           764  TONY STARK
# 5122         5122  TONY STARK
# 15645       15645  TONY STARK
#
#                                                     line              movie  \
# 683    ive seen the papers ive heard the reports that...           Iron Man
# 691    i know that its confusing it is one thing to q...         Iron Man 2
# 764    well you can forget it i am iron man the suit ...         Iron Man 2
# 5122   so if i were to wrap this up tie it with a bow...         Iron Man 3
# 15645                                   and iam iron man  Avengers: Endgame
#
#        year  words  Adam McKay  Anna Boden  Art Marcum  Ashley Edward Miller  \
# 683    2008     31       False       False        True                 False
# 691    2010     58       False       False       False                 False
# 764    2010     46       False       False       False                 False
# ...

# %%
dialogue['compressed']=dialogue['line'].apply(lambda x: ''.join(x.split(" ")))

# %%
dialogue['CP_AA_compressed']=dialogue['compressed'].apply(lambda x: "avengersassemble" in x)

# %%
dialogue[dialogue['CP_AA_compressed']==True]
# Out:
#        Unnamed: 0     character              line              movie  year  \
# 15592       15592  STEVE ROGERS  avengersassemble  Avengers: Endgame  2019
#
#        words  Adam McKay  Anna Boden  Art Marcum  Ashley Edward Miller  ...  \
# 15592      1       False       False       False                 False  ...
#
#        Shane Black  Stephen McFeely  Zack Stentz  Catchphrase-IM  \
# 15592        False             True        False           False
#
#        Catchphrase-IR  Catchphrase-AD  Catchphrase-AA        compressed  \
# 15592           False           False            True  avengersassemble
#
#        CP_IM_compressed  CP_AA_compressed
# 15592             False              True
#
# [1 rows x 45 columns]

# %%
dialogue['line'][683]
# Out:
# 'ive seen the papers ive heard the reports thats why i want to put an end to all this wild speculation the truth is i am iron man'

# %%
dialogue['Catchphrase-OL']=dialogue['line'].apply(lambda x: "on your left" in x)

# %%
dialogue[dialogue['Catchphrase-OL']==True]
# Out:
#        Unnamed: 0     character  \
# 5845         5845  STEVE ROGERS
# 5847         5847  STEVE ROGERS
# 6612         6612  STEVE ROGERS
# 15588       15588    SAM WILSON
#
#                                                     line  \
# 5845                           on your left on your left
# 5847                                        on your left
# 6612   then finish it cause im with you to the end of...
# 15588                                   cap on your left
#
#                                      movie  year  words  Adam McKay  \
# 5845   Captain America: The Winter Soldier  2014      6       False
# 5847   Captain America: The Winter Soldier  2014      3       False
# 6612   Captain America: The Winter Soldier  2014     17       False
# 15588                    Avengers: Endgame  2019      5       False
#
#        Anna Boden  Art Marcum  Ashley Edward Miller  ...  Catchphrase-IR  \
# 5845        False       False                 False  ...           False
# ...

# %%
dialogue['line'][11297]
# Out:
# 'here we are end of the line'

# %%
dialogue['Catchphrase-H']=dialogue['line'].apply(lambda x: "we have a hulk" in x)

# %%
dialogue[dialogue['Catchphrase-H']==True]
# Out:
#        Unnamed: 0   character  \
# 3981         3981  TONY STARK
# 13007       13007        LOKI
#
#                                                     line  \
# 3981                                      we have a hulk
# 13007  well for one thing im not asgardian and for an...
#
#                         movie  year  words  Adam McKay  Anna Boden  \
# 3981             The Avengers  2012      4       False       False
# 13007  Avengers: Infinity War  2018     14       False       False
#
#        Art Marcum  Ashley Edward Miller  ...  Catchphrase-AD  Catchphrase-AA  \
# 3981        False                 False  ...           False           False
# 13007       False                 False  ...           False           False
#
#                                               compressed  CP_IM_compressed  \
# 3981                                         wehaveahulk             False
# 13007  wellforonethingimnotasgardianandforanotherweha...             False
#
# ...

# %%
dialogue['line'][13007]
# Out:
# 'well for one thing im not asgardian and for another we have a hulk'

# %%
dialogue['Catchphrase-p']=dialogue['line'].apply(lambda x: "i am groot" in x)

# %%
dialogue[dialogue['Catchphrase-p']==True]
# Out:
#        Unnamed: 0 character                              line  \
# 9400         9400     GROOT                        i am groot
# 9818         9818     GROOT                        i am groot
# 9820         9820     GROOT                        i am groot
# 9822         9822     GROOT                        i am groot
# 9824         9824     GROOT                        i am groot
# 10006       10006     GROOT                        i am groot
# 10008       10008     GROOT                        i am groot
# 10079       10079     GROOT                        i am groot
# 10081       10081     GROOT                        i am groot
# 10083       10083     GROOT                        i am groot
# 10085       10085     GROOT  i am groot i am groot i am groot
# 10133       10133     GROOT                        i am groot
# 10148       10148     GROOT                        i am groot
# 10150       10150     GROOT                        i am groot
# ...

# %%
dialogue['line'][13489]
# Out:
# 'its just  you cant be a friendly neighborhood spiderman if theres no neighborhood okay that didnt really make any sense but you know what im trying to say'

# %%
dialogue['compressed']=dialogue['line'].apply(lambda x: ''.join(x.split(" ")))

# %%
dialogue['CP_IG_compressed']=dialogue['compressed'].apply(lambda x: "iamgroot" in x)

# %%
dialogue[dialogue['CP_IG_compressed']==True]
# Out:
#        Unnamed: 0 character                              line  \
# 9400         9400     GROOT                        i am groot
# 9818         9818     GROOT                        i am groot
# 9820         9820     GROOT                        i am groot
# 9822         9822     GROOT                        i am groot
# 9824         9824     GROOT                        i am groot
# 10006       10006     GROOT                        i am groot
# 10008       10008     GROOT                        i am groot
# 10079       10079     GROOT                        i am groot
# 10081       10081     GROOT                        i am groot
# 10083       10083     GROOT                        i am groot
# 10085       10085     GROOT  i am groot i am groot i am groot
# 10133       10133     GROOT                        i am groot
# 10148       10148     GROOT                        i am groot
# 10150       10150     GROOT                        i am groot
# ...
